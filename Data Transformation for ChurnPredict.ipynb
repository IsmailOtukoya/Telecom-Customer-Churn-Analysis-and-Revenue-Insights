# %%
import pandas as pd

df  = pd.read_csv(r"C:/Users/ISMAIL/OneDrive/Documents/data science projects/cleanedandanalyzed_dataset.csv")

# %%
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...  Monthly Charge  \
# 0     93225  34.827662 -118.999073                    2  ...        0.064217
# 1     91206  34.162515 -118.203869                    0  ...       -2.166213
# 2     92627  33.645672 -117.922613                    0  ...        0.330202
# 3     94553  38.014457 -122.115432                    1  ...        1.102521
# 4     93010  34.227846 -119.079903                    3  ...        0.650666
#
#   Total Charges Total Refunds Total Extra Data Charges  \
# ...

# %%
#Data type conversion
#Convert "Gender," "Married," "City," "Offer," and other categorical columns from object to the appropriate data type (e.g., category or boolean).
#Convert "Avg Monthly GB Download" from object to a numeric data type (e.g., float) for easier analysis.

df['Gender'] = df['Gender'].astype('category')
df['Married'] = df['Married'].astype('category')
df['City'] = df['City'].astype('category')
df['Offer'] = df['Offer'].astype('category')
df['Avg Monthly GB Download'] = pd.to_numeric(df['Avg Monthly GB Download'], errors='coerce') 
df['Gender'] = df['Gender'].astype('category')
df['Married'] = df['Married'].astype('category')
df['City'] = df['City'].astype('category')
df['Offer'] = df['Offer'].astype('category')
df['Avg Monthly GB Download'] = pd.to_numeric(df['Avg Monthly GB Download'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Github_Folder\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\Documents\Github_Folder\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Documents\Github_Folder\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Avg Monthly GB Download'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.dtypes
# Out:
# Customer ID                      object
# Gender                         category
# Age                               int64
# Married                        category
# Number of Dependents              int64
# City                           category
# Zip Code                          int64
# Latitude                        float64
# Longitude                       float64
# Number of Referrals               int64
# Tenure in Months                  int64
# Offer                          category
# Phone Service                    object
# Internet Service                 object
# Internet Type                    object
# Online Security                  object
# Online Backup                    object
# Device Protection Plan           object
# Premium Tech Support             object
# Streaming TV                     object
# Streaming Movies                 object
# Streaming Music                  object
# Unlimited Data                   object
# ...

# %%
# Creating a new column for age group based on the 'Age' column
df['Age Group'] = pd.cut(df['Age'], bins=[0, 17, 24, 34, 44, 54, 64, 200], labels=['0-17', '18-24', '25-34', '35-44', '45-54', '55-64', '65+'])

# Creating a binary variable indicating whether a customer has dependents
df['Has Dependents'] = df['Number of Dependents'].apply(lambda x: 1 if x > 0 else 0)

# Calculating the total charges per month
df['Total Charges Per Month'] = df['Monthly Charge'] + df['Total Charges'] - df['Total Refunds'] + df['Total Extra Data Charges'] + df['Total Long Distance Charges']

# Display the updated DataFrame
print(df)
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# ...

# %%
# Select the numerical columns for standardization
numeric_columns = ['Monthly Charge', 'Total Charges', 'Total Refunds', 'Total Extra Data Charges', 'Total Long Distance Charges']

# Perform z-score normalization on the selected columns
df[numeric_columns] = (df[numeric_columns] - df[numeric_columns].mean()) / df[numeric_columns].std()

# %%
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...  Monthly Charge  \
# 0     93225  34.827662 -118.999073                    2  ...        0.064217
# 1     91206  34.162515 -118.203869                    0  ...       -2.166213
# 2     92627  33.645672 -117.922613                    0  ...        0.330202
# 3     94553  38.014457 -122.115432                    1  ...        1.102521
# 4     93010  34.227846 -119.079903                    3  ...        0.650666
#
#   Total Charges Total Refunds Total Extra Data Charges  \
# ...

# %%
df.dtypes
# Out:
# Customer ID                      object
# Gender                         category
# Age                               int64
# Married                        category
# Number of Dependents              int64
# City                           category
# Zip Code                          int64
# Latitude                        float64
# Longitude                       float64
# Number of Referrals               int64
# Tenure in Months                  int64
# Offer                          category
# Phone Service                    object
# Internet Service                 object
# Internet Type                    object
# Online Security                  object
# Online Backup                    object
# Device Protection Plan           object
# Premium Tech Support             object
# Streaming TV                     object
# Streaming Movies                 object
# Streaming Music                  object
# Unlimited Data                   object
# ...

# %%
df.to_csv('C:/Users/ISMAIL/OneDrive/Documents/data science projects/cleanedandanalyzed_dataset.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.to_csv('C:/Users/ISMAIL/OneDrive/Documents/data science projects/cleanedandanalyzed_dataset.csv', index=False)
#
# File ~\Documents\Github_Folder\lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
# ...
